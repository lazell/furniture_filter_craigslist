# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

url = "https://newyork.craigslist.org/d/furniture/search/fua"

# Getting the webpage, creating a Response object.
response = requests.get(url)

# Extracting the source code of the page.
data = response.text

# Passing the source code to Beautiful Soup to create a BeautifulSoup object for it.
soup = BeautifulSoup(data, 'lxml')

# Extracting all the &lt;a&gt; tags whose class name is 'result-title' into a list.
titles = soup.findAll('a', {'class': 'result-title hdrlnk'})

# Extracting text from the the &lt;a&gt; tags, i.e. class titles.

lst = [title.text for title in titles]

# %%
links = titles.get('href')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-c909118ab281> in <module>()
# ----> 1 links = titles.get('href')
#       2 links
#
# /anaconda2/lib/python2.7/site-packages/bs4/element.pyc in __getattr__(self, key)
#    1805     def __getattr__(self, key):
#    1806         raise AttributeError(
# -> 1807             "ResultSet object has no attribute '%s'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?" % key
#    1808         )
#
# AttributeError: ResultSet object has no attribute 'get'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?

# %%
df = pd.DataFrame(lst)
df
# Out:
#                                                      0
# 0                             Ikea MALM 6-drawer chest
# 1          IKEA Entertainment Center - Excellent Shape
# 2               Solid Wood Table - Excellent Condition
# 3      Anthropologie Elowen Chair for sale- never used
# 4                              Table in Good Condition
# 5                       Crate&Barrel Folding Bookshelf
# 6                          Junior bedroom set for sale
# 7    Bathroom Vanity with Faucet, Stone Counter-top...
# 8                                 Leaning 54" TV stand
# 9    Bathroom Vanity with Stone Counter-top- Excell...
# 10                               Antique Moroccan bowl
# 11                                    Console West Elm
# 12                                    Handcrafted Bowl
# 13                             Vintage decorative bowl
# 14                                  Black Office Chair
# 15                 Room & Board -- Couch and Chair Set
# 16        DRESSER FOR SALE - DRESSERS (delivery extra)
# 17           Vintage wood night stand (delivery extra)
# 18         Vintage wood coffee table  (delivery extra)
# 19     Black brown bookshelf 36" tall (delivery extra)
# 20                                  Metal storage rack
# 21             Computer desk  31 wide (delivery extra)
# 22                  Swivel Gray Suede Armchair / Chair
# 23   Light wood rising top coffee table (delivery e...
# 24   Large wood organizer shelves cart on wheels 48...
# 25   Small white side table night stand (delivery e...
# 26            2 wood swivel high top chairs bar stools
# 27                                 Bamboo Wood Shelves
# 28                                               Table
# 29                            L COUCH!!! 6 Person SOHO
# ..                                                 ...
# 90   Danish mid century modern armless sofa couch d...
# 91                                         Ikea shelve
# 92   Vintage Paul Mccobb mid century 2 drawer night...
# 93   vintage mid century Paul Mccobb Pair of arm ch...
# 94   Danish mid century modern sofa couch daybed cl...
# 95   Vintage mid century Paul Mccobb pair nightstan...
# 96   Vintage Paul Mccobb mid century 6 drawer 48" L...
# 97   Vintage Paul Mccobb Mid Century Modern Coffee ...
# 98   Vintage Paul Mccobb mid century modern coffee ...
# 99   Vintage mid century Paul Mccobb 8 drawer dress...
# 100  Vintage Paul Mccobb mid century 1 drawer night...
# 101  Vintage mid century Paul Mccobb 4 + 2 drawer d...
# 102                            Wooden table and chairs
# 103  Vintage mid century Danish lounge chair  solid...
# 104  Vintage Paul Mccobb mid century cabinet 60" L ...
# 105                         Betsy Marek Black Sofa Bed
# 106  Vintage mid century Paul Mccobb 5 drawer maple...
# 107      West Elm Vintage-Inspired Cylinder Floor Lamp
# 108  Vintage Paul Mccobb Mid Century Modern Coffee ...
# 109                                       Antique Desk
# 110  Vintage mid century Danish lounge chair  pair ...
# 111  Vintage Danish modern maple low sofa couch mid...
# 112                                Antique Round Table
# 113                  Outdoor Bistro Table and 2 Chairs
# 114                               Tv stand glass doors
# 115                                 Student desk chair
# 116  Like New Italian Drafting Table w/ Mayline 60"...
# 117         NEW Alston Contemporary 6 Piece Dining Set
# 118  NEW Full Mirror Wardrobe available in Many Colors
# 119        Set of Two Napoli Swivel Bar stool in Vinyl
#
# [120 rows x 1 columns]
